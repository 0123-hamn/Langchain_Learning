# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %% [markdown]
# ## Streaming

# %%
for chunk in model.stream("What is Langchain ?"):
    print(chunk.text,end="|",flush=True)
# Out:
# **LangChain is a framework designed| to simplify the development of applications that leverage Large Language Models (LLMs).**
#
# Think of it as a toolkit that allows developers to go beyond just sending a single prompt to an LLM and instead build complex, multi-step, and context-|aware applications.
#
# ### Why was LangChain created? (The Problem it Solves)
#
# While LLMs are incredibly powerful, they have some inherent limitations when used in isolation for real-world applications:
#
# 1.  **Limited Knowledge|:** LLMs have a knowledge cut-off date and don't have access to real-time information or private data.
# 2.  **Lack of Memory:** A raw LLM call is stateless; it "forgets" previous| interactions.
# 3.  **Inability to Act:** LLMs can generate text, but they can't directly interact with external systems (e.g., search the web, call an API, query a database).
# 4.  **|Complex Workflows:** Building applications often requires chaining multiple LLM calls together, potentially with intermediate processing steps.
#
# LangChain addresses these limitations by providing a structured way to combine LLMs with other data sources and computational tools.
#
# ### Core Concepts| and Components of LangChain:
#
# LangChain is built around several modular components that can be combined in various ways:
#
# 1.  **Models:**
#     *   **LLMs:** Interfaces to various Large Language Models (e.g|., OpenAI's GPT series, Anthropic's Claude, Hugging Face models).
#     *   **Chat Models:** Optimized for conversational interactions.
#     *   **Embeddings:** Tools for converting text into numerical vectors, essential for similarity| search.
#
# 2.  **Prompts:**
#     *   **Prompt Templates:** Standardized ways to construct prompts, including variables and few-shot examples.
#     *   **Output Parsers:** Structuring the LLM's raw| text output into more usable formats (e.g., JSON, Pydantic objects).
#
# 3.  **Chains:**
#     *   These are sequences of calls to LLMs or other utilities. Chains allow you to combine multiple steps, such| as:
#         *   Loading data -> Summarizing with an LLM.
#         *   Taking user input -> Formatting a prompt -> Calling an LLM.
#         *   Retrieving relevant documents -> Answering a question based on those documents (|RAG).
#
# 4.  **Retrieval:**
#     *   **Document Loaders:** Tools to load data from various sources (PDFs, websites, databases, etc.).
#     *   **Text Splitters:** Breaking down| large documents into smaller, manageable chunks.
#     *   **Vector Stores:** Databases designed to store and query embeddings, enabling semantic search (e.g., Pinecone, Chroma, FAISS).
#     *   **Retrievers:** Fetch|ing relevant documents based on a query, often used in **RAG (Retrieval Augmented Generation)** applications.
#
# 5.  **Memory:**
#     *   Allows LLMs to remember past interactions within a conversation. LangChain offers different| types of memory (e.g., conversational buffer memory, entity memory).
#
# 6.  **Agents:**
#     *   This is one of LangChain's most powerful features. Agents allow an LLM to decide *what action| to take next* based on available tools.
#     *   The LLM acts as a "reasoning engine," observing the environment, thinking about the problem, and choosing a tool to use.
#     *   This enables dynamic, multi|-step problem-solving.
#
# 7.  **Tools:**
#     *   Functions that an agent can call to interact with the outside world. Examples include:
#         *   Google Search
#         *   A calculator
#         *   AP|Is for specific services (weather, stock data, CRM)
#         *   Database query tools
#
# ### Key Use Cases for LangChain:
#
# *   **Question Answering over Custom Documents:** Building chatbots that can answer questions based on your private| documents (e.g., company manuals, research papers). This is often achieved with RAG.
# *   **Chatbots with Memory:** Creating conversational AI that remembers context from previous turns.
# *   **Data Extraction and Summarization:** Automatically| extracting structured information or summarizing lengthy texts.
# *   **Agentic Workflows:** Automating complex tasks by allowing an LLM to choose and use various tools to achieve a goal (e.g., "Find me restaurants in Paris,| check their ratings, and book a table").
# *   **Content Generation:** Generating various forms of content (articles, marketing copy, code) while integrating with external data sources or tools.
#
# ### LangChain Ecosystem:
#
# *   **LangSmith|:** A platform for debugging, monitoring, and evaluating LLM applications built with LangChain. It helps visualize chains, trace calls, and collect feedback.
# *   **LangServe:** A library for deploying LangChain runnables and chains as REST| APIs.
#
# ### In Summary:
#
# LangChain is a crucial framework for anyone looking to build sophisticated, production-ready applications powered by Large Language Models. It provides the abstractions, components, and tools necessary to overcome the limitations of raw LLMs| and create intelligent systems that can reason, remember, and interact with the real world.||

# %% [markdown]
# ### Batching

# %%
responses = model.batch([
    "What is langchain ?",
    "Importance of langchain",
    "Advantages of using langchain"],
    config = {
        'max_concurrency':5
    }
    )
for response in responses:
    print(response)
# Out:
# content='**LangChain is a powerful open-source framework designed to simplify the development of applications powered by Large Language Models (LLMs).**\n\nIn essence, it acts as a toolkit that allows developers to connect LLMs to external data sources, enable them to interact with their environment (e.g., use tools, perform actions), and build complex, multi-step LLM workflows.\n\nThink of it this way: LLMs are incredibly powerful at generating text, understanding context, and answering questions. However, by themselves, they have limitations:\n\n1.  **Lack of Real-time Information:** Their knowledge is often frozen at their training data cutoff.\n2.  **No Memory:** They don\'t inherently remember previous interactions in a conversation.\n3.  **Limited Action Capability:** They can\'t directly interact with external systems (like searching the web, calling an API, or accessing a database).\n4.  **Single-Turn Interactions:** They typically respond to one prompt at a time, making multi-step reasoning difficult.\n\n**LangChain bridges these gaps by providing:**\n\n1.  **Components:** Modular abstractions for common LLM functionalities.\n2.  **Chains:** Pre-built sequences of calls that allow you to combine different components to achieve specific tasks.\n3.  **Agents:** LLMs that can reason about which actions to take, observe the results, and repeat until a task is complete.\n\n---\n\n### Key Concepts and Components of LangChain:\n\n1.  **Models:** Integrates with various LLM providers (OpenAI, Hugging Face, Anthropic, etc.) and different types of models (LLMs for text generation, Chat Models for conversational AI, Embeddings for text representation).\n2.  **Prompts:** Tools for constructing and managing prompts effectively, including prompt templates, few-shot examples, and output parsers.\n3.  **Chains:** Sequences of calls to LLMs or other utilities. For example, you might have a chain that takes a user question, retrieves relevant documents, and then uses an LLM to answer the question based on those documents.\n4.  **Agents:** The most sophisticated part. An agent uses an LLM as a "reasoning engine" to decide which "tools" to use (like a search engine, a calculator, or a custom API call) to achieve a goal. It can then observe the tool\'s output and decide on the next action.\n5.  **Retrieval:** Components for getting relevant data into your LLM application. This includes:\n    *   **Document Loaders:** For loading data from various sources (PDFs, web pages, databases).\n    *   **Text Splitters:** For breaking down large documents into manageable chunks.\n    *   **Vector Stores:** For storing and querying embeddings of your data, enabling semantic search (e.g., Pinecone, Chroma, FAISS).\n6.  **Memory:** Mechanisms to persist state between calls of a chain or agent, crucial for building conversational applications.\n7.  **Tools:** External functionalities that an agent can use, such as Google Search, a Python interpreter, a database query tool, or custom APIs.\n\n---\n\n### Why is LangChain Important?\n\n*   **Simplifies Complexity:** Makes it much easier to build sophisticated LLM applications that go beyond simple prompt-response.\n*   **Enhances LLM Capabilities:** Extends LLMs with real-time data access, memory, and the ability to interact with the world.\n*   **Accelerates Development:** Provides pre-built components and patterns, reducing boilerplate code and speeding up the development process.\n*   **Enables New Use Cases:** Makes applications like intelligent chatbots, question-answering systems over custom documents (RAG - Retrieval Augmented Generation), data extraction agents, and autonomous task executors more feasible.\n*   **Modularity:** Promotes building modular and reusable components.\n\nLangChain is available in **Python** and **JavaScript/TypeScript**, making it accessible to a wide range of developers. It has quickly become a cornerstone in the ecosystem for building practical and powerful LLM-powered  ...
# content='LangChain is a powerful open-source framework designed to simplify the development of applications powered by large language models (LLMs). Its importance stems from its ability to address several key limitations and challenges faced when building sophisticated LLM-driven systems.\n\nHere are the main reasons for LangChain\'s importance:\n\n1.  **Bridging the Gap Between LLMs and the Real World:**\n    *   **Access to External Data (RAG - Retrieval Augmented Generation):** LLMs are trained on vast datasets but have a knowledge cutoff. LangChain makes it easy to connect LLMs to external, up-to-date, or proprietary data sources (databases, documents, APIs, web search) via "retrieval." This allows applications to provide accurate, context-specific, and current information, significantly reducing hallucinations.\n    *   **Tools and Actions:** LLMs are primarily text generators. LangChain enables them to "act" by providing a mechanism to define and use external "tools" (e.g., a calculator, a weather API, a booking system, a code interpreter). This transforms LLMs from mere conversational agents into intelligent agents capable of performing tasks in the real world.\n\n2.  **Simplifying Complex LLM Workflows (Orchestration):**\n    *   **Chains:** Many LLM applications require multiple steps (e.g., summarize a document, then answer a question based on the summary, then translate the answer). LangChain\'s "chains" allow you to define sequences of LLM calls and other utilities, abstracting away the complexity of managing intermediate steps and prompts.\n    *   **Agents:** For more dynamic and adaptive behavior, "agents" allow an LLM to decide *which* tools to use and *when* to use them based on user input. This enables more flexible problem-solving where the LLM can reason about the best course of action.\n\n3.  **Enhancing LLM Capabilities:**\n    *   **Memory:** Standard LLMs have a limited context window, making it hard to maintain long-term conversation history. LangChain offers various "memory" components to store and retrieve past interactions, enabling more coherent and context-aware chatbots and assistants over extended dialogues.\n    *   **Prompt Management:** It provides utilities for structuring, templating, and managing prompts, which is crucial for consistency, efficiency, and fine-tuning LLM behavior.\n\n4.  **Modularity and Flexibility:**\n    *   **LLM Agnostic:** LangChain supports a wide range of LLMs (OpenAI, Anthropic, Google, Hugging Face models, etc.), allowing developers to switch between providers or models with minimal code changes.\n    *   **Component-Based:** Its modular design means you can mix and match different components (e.g., various vector stores, memory types, tools) to build highly customized solutions.\n\n5.  **Rapid Prototyping and Development:**\n    *   By providing pre-built abstractions and integrations, LangChain significantly reduces the boilerplate code required to develop sophisticated LLM applications. This accelerates the development cycle from idea to prototype to production.\n\n6.  **Community and Ecosystem:**\n    *   LangChain has a large and active community, leading to continuous improvements, new integrations, and a wealth of shared knowledge and examples. This vibrant ecosystem makes it easier for developers to find solutions and best practices.\n\n**In summary, LangChain is important because it:**\n\n*   **Empowers LLMs** to go beyond basic text generation by connecting them to external data and actions.\n*   **Simplifies the development process** for complex LLM applications through structured workflows (chains, agents).\n*   **Enhances core LLM functionalities** like memory and context management.\n*   **Promotes modularity and flexibility**, allowing developers to build robust and adaptable systems.\n*   **Accelerates innovation** in the field of AI by lowering the barrier to entry for building advanced LLM applications.\n\nWhile it has a learning curve and can s ...
# content='LangChain is a powerful framework designed to simplify the development of applications powered by large language models (LLMs). It provides a structured way to combine LLMs with other sources of data and computation, enabling more complex and intelligent applications than simple API calls to an LLM.\n\nHere are the key advantages of using LangChain:\n\n1.  **Orchestration and Chaining:**\n    *   **Problem:** LLM applications often require multiple steps (e.g., retrieve data, summarize, ask a follow-up question, call an external API).\n    *   **LangChain Solution:** It allows you to define **"chains"** of operations. You can link multiple LLM calls, data retrieval steps, or other computations together in a logical sequence.\n    *   **Advantage:** Simplifies complex workflows, making it easy to build multi-step reasoning processes.\n\n2.  **Agentic Behavior:**\n    *   **Problem:** LLMs are powerful but passive. They can\'t *do* things in the real world or decide what tool to use.\n    *   **LangChain Solution:** Provides **"agents"** that can use LLMs as a reasoning engine to decide which "tools" (e.g., search engines, code interpreters, custom APIs) to use and in what order, based on the user\'s input.\n    *   **Advantage:** Empowers LLMs with external capabilities, allowing them to perform actions, browse the web, run code, and interact with external systems autonomously.\n\n3.  **Context Management and Memory:**\n    *   **Problem:** LLMs have a limited "context window" and are stateless. They don\'t remember previous interactions in a conversation.\n    *   **LangChain Solution:** Offers various **"memory"** modules to store and retrieve past conversation turns, summaries, or other relevant information, injecting it back into the LLM\'s prompt.\n    *   **Advantage:** Enables stateful, conversational AI applications that maintain context over time, leading to more natural and coherent interactions.\n\n4.  **Grounding LLMs with External Data (RAG - Retrieval Augmented Generation):**\n    *   **Problem:** LLMs are trained on vast datasets but lack knowledge of private, proprietary, or up-to-the-minute information.\n    *   **LangChain Solution:** Integrates seamlessly with various **document loaders, text splitters, embedding models, and vector stores**. This allows you to retrieve relevant chunks of your own data and provide them as context to the LLM.\n    *   **Advantage:** Makes LLMs accurate and relevant to specific use cases by giving them access to your custom knowledge base, reducing hallucinations and improving factual accuracy.\n\n5.  **Modularity and Reusability:**\n    *   **Problem:** Building LLM applications from scratch can be repetitive and hard to maintain.\n    *   **LangChain Solution:** Provides modular components (LLMs, Prompts, Chains, Agents, Tools, Memory, Document Loaders, etc.) that can be combined and reused.\n    *   **Advantage:** Speeds up development, promotes code reusability, and makes applications easier to understand, debug, and scale.\n\n6.  **Vendor Agnostic and Component Flexibility:**\n    *   **Problem:** Developers often want to experiment with different LLM providers (OpenAI, Anthropic, Hugging Face, etc.), vector stores (Pinecone, Weaviate, Chroma), or other components.\n    *   **LangChain Solution:** Offers standardized interfaces for various components, allowing you to swap out different LLM providers, embedding models, vector stores, etc., with minimal code changes.\n    *   **Advantage:** Provides flexibility, reduces vendor lock-in, and allows developers to choose the best tools for their specific needs and budget.\n\n7.  **Prompt Engineering and Templates:**\n    *   **Problem:** Crafting effective prompts is crucial for LLM performance and can be complex.\n    *   **LangChain Solution:** Provides **"prompt templates"** to easily manage and format prompts, including variables and few-shot examples.\n    *   **Advantage:** Streamlines prompt engineering, makes pro ...

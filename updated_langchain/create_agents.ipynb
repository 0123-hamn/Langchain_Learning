# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ['GROQ_API_KEY'] = os.getenv('GROQ_API_KEY') 
os.environ['GOOGLE_API_KEY'] = os.getenv('GOOGLE_API_KEY')

# %%
from langchain.agents import create_agent

def get_weather(city:str)->str:
    '''Get the weather for the city'''
    return f"The weather in the {city} is sunny."

agent = create_agent(
    model = "groq:llama-3.1-8b-instant",
    tools = [get_weather],
    system_prompt = "You are a helpful assitant."
)
agent

# %%
response = agent.invoke({"messages": "what is weather in kolkata"})

# %%
response['messages']
# Out:
# [HumanMessage(content='what is weather in kolkata', additional_kwargs={}, response_metadata={}, id='c8700487-a333-4079-a874-65a67058b3ae'),
# ...

# %% [markdown]
# ### Model-Integration

# %%
## Google er integration
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-2.5-flash")
response = model.invoke("What is LangChain?")
print(response.content)
# Out:
# **LangChain** is a powerful open-source framework designed to simplify the development of applications that leverage Large Language Models (LLMs).
#
# In essence, it acts as an **orchestration layer** that allows developers to connect LLMs with other sources of computation and data, enabling them to build more complex, stateful, and context-aware applications than would be possible by just interacting with an LLM directly.
#
# Think of it as a toolkit that provides "building blocks" and "recipes" for creating sophisticated LLM-powered applications.
#
# ### Key Concepts and What LangChain Provides:
#
# 1.  **Models:**
#     *   **LLMs:** Provides a standardized interface to connect with various LLM providers (OpenAI, Hugging Face, Anthropic, Google, etc.) and different model types (text generation, chat models).
#     *   **Chat Models:** Specifically designed for conversational AI, managing message history.
#
# 2.  **Prompts:**
# ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
response = model.invoke('Who is worlds best Batsman in history of international cricket ?')
response.content
# Out:
# 'Ah, the million-dollar question in cricket! It\'s incredibly difficult to definitively name the "world\'s best batsman in history" because the game has evolved so much across different eras, formats (Test, ODI, T20), and conditions. However, there are a few names that consistently come up in the discussion, each with a strong claim:\n\n1.  **Sir Don Bradman (Australia):**\n    *   **Why he\'s often considered the greatest:** His Test batting average of **99.94** is so astronomically higher than anyone else\'s in the history of the game that it almost defies belief. To put it in perspective, the next best average for a batsman with a significant career is usually in the mid-60s. He played in an era with uncovered pitches, no helmets, and fewer matches, yet dominated like no other.\n    *   **The Caveat:** He only played Test cricket and his career was relatively short (1928-1948, interrupted by war).\n\n2.  **Sachin Tendulkar (India):**\n    *   **Why he\'s a strong contender:** The 
# ...

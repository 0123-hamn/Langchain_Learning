# %%
from langchain_text_splitters import HTMLHeaderTextSplitter
from langchain_community.document_loaders import WebBaseLoader

url = "https://www.youtube.com/"
loader = WebBaseLoader(url)
docs = loader.load()

headers_to_split_on = [
    ("h1", "Header 1"),
    ("h2", "Header 2"),
    ("h3", "Header 3"),
    ("h4", "Header 4"),
    ("h5", "Header 5"),
    ("h6", "Header 6"),
]

text_splitter = HTMLHeaderTextSplitter(headers_to_split_on=headers_to_split_on)


splits = text_splitter.split_text(docs[0].page_content)

splits[0]
# Out:
# Document(metadata={}, page_content='YouTubeAboutPressCopyrightContact usCreatorsAdvertiseDevelopersTermsPrivacyPolicy & SafetyHow YouTube worksTest new features© 2025 Google LLC')

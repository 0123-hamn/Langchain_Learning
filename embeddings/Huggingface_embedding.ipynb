# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["HF_TOKEN"] = os.getenv("HF_TOKEN")

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeeddings = HuggingFaceEmbeddings(model_name="Qwen/Qwen3-Embedding-0.6B")

# %%
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader("PriyamResume.pdf")
docs = loader.load()

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
texts = text_splitter.split_documents(docs)
texts
# Out:
# [Document(metadata={'producer': 'ONLYOFFICE/9.0.0.172', 'creator': 'ONLYOFFICE/9.0.0.172', 'creationdate': '2025-07-03T01:57:52+00:00', 'author': 'Rishabh Mishra', 'moddate': '2025-07-03T01:57:52+00:00', 'source': 'PriyamResume.pdf', 'total_pages': 2, 'page': 0, 'page_label': '1'}, page_content='Priyam Roy\nPortfolio\nPROFILE\nI am an enthuastic B.Tech CSE student of 3rd year with strong skills in C, HTML, CSS, JavaScript, Bootstrap, and exploring the\nMERN stack. I am passionate about full stack development and eager to gain hand-on experience through an internship.\nEDUCATION\nNarulaInstituteofTechnology Kolkata , India\nBachelor of TechnologyinComputerScienceEngineering 2023–2027\n· 1st year YGPA 8.19\n· 2nd year 3rd semeseter SGPA 9.01\nKharagpur Atulmoni Polytechnic High School (H.S)\n· Higher Secondary(Class XII, WBCHSE), 2023 - 73%. Kharagpur,India\n· Secondary (Class X, WBBSE), 2021 - 91%\nWORK EXPERIENCE\nCurrently I have no work experience. Looking forward to get some soon.
# ...

# %%
from langchain_community.vectorstores import Chroma
vectorstore = Chroma.from_documents(texts,embeeddings)
vectorstore

# %%
query = "Technical Skills"
retrived_query = vectorstore.similarity_search(query)
retrived_query
# Out:
# [Document(metadata={'creator': 'ONLYOFFICE/9.0.0.172', 'source': 'PriyamResume.pdf', 'page_label': '1', 'total_pages': 2, 'moddate': '2025-07-03T01:57:52+00:00', 'author': 'Rishabh Mishra', 'creationdate': '2025-07-03T01:57:52+00:00', 'producer': 'ONLYOFFICE/9.0.0.172', 'page': 0}, page_content='Priyam Roy\nPortfolio\nPROFILE\nI am an enthuastic B.Tech CSE student of 3rd year with strong skills in C, HTML, CSS, JavaScript, Bootstrap, and exploring the\nMERN stack. I am passionate about full stack development and eager to gain hand-on experience through an internship.\nEDUCATION\nNarulaInstituteofTechnology Kolkata , India\nBachelor of TechnologyinComputerScienceEngineering 2023–2027\n· 1st year YGPA 8.19\n· 2nd year 3rd semeseter SGPA 9.01\nKharagpur Atulmoni Polytechnic High School (H.S)\n· Higher Secondary(Class XII, WBCHSE), 2023 - 73%. Kharagpur,India\n· Secondary (Class X, WBBSE), 2021 - 91%\nWORK EXPERIENCE\nCurrently I have no work experience. Looking forward to get some soon.
# ...

# %%
retrived_query[0].page_content
# Out:
# 'Priyam Roy\nPortfolio\nPROFILE\nI am an enthuastic B.Tech CSE student of 3rd year with strong skills in C, HTML, CSS, JavaScript, Bootstrap, and exploring the\nMERN stack. I am passionate about full stack development and eager to gain hand-on experience through an internship.\nEDUCATION\nNarulaInstituteofTechnology Kolkata , India\nBachelor of TechnologyinComputerScienceEngineering 2023–2027\n· 1st year YGPA 8.19\n· 2nd year 3rd semeseter SGPA 9.01\nKharagpur Atulmoni Polytechnic High School (H.S)\n· Higher Secondary(Class XII, WBCHSE), 2023 - 73%. Kharagpur,India\n· Secondary (Class X, WBBSE), 2021 - 91%\nWORK EXPERIENCE\nCurrently I have no work experience. Looking forward to get some soon.\nSKILLS\nTechnical Skills:\nProgramming Languages:C, JavaScript\nWeb Technologies:HTML5, CSS3, Bootstrap\nFrontend Framework:React.js (basic)\nBackend: Node.js (basic), Express.js (basic)\nDatabase: MongoDB (basic)\nTools & Platforms:Visual Studio Code, Git/GitHub'
